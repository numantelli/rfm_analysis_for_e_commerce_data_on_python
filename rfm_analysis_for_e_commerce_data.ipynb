# %%
import pandas as pd

# Loading of data
data = pd.read_csv('e-comerce.csv',  encoding='unicode_escape')

# %%
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...                 ...        ...         ...             ...
# 541904  12/9/2011 12:50       0.85     12680.0          France
# 541905  12/9/2011 12:50       2.10     12680.0          France
# 541906  12/9/2011 12:50       4.15     12680.0          France
# 541907  12/9/2011 12:50       4.15     12680.0          France
# 541908  12/9/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    406829 non-null  object
#  1   StockCode    406829 non-null  object
#  2   Description  406829 non-null  object
#  3   Quantity     406829 non-null  int64
#  4   InvoiceDate  406829 non-null  datetime64[ns]
#  5   UnitPrice    406829 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      406829 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 27.9+ MB

# %%
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
data.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID Country
# 541904 2011-12-09 12:50:00       0.85     12680.0  France
# 541905 2011-12-09 12:50:00       2.10     12680.0  France
# 541906 2011-12-09 12:50:00       4.15     12680.0  France
# 541907 2011-12-09 12:50:00       4.15     12680.0  France
# 541908 2011-12-09 12:50:00       4.95     12680.0  France

# %%
data.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
data = data.dropna() # Cleaning of null values

# %%
data.shape
# Out:
# (406829, 8)

# %%
data["InvoiceDate"] = pd.to_datetime(data["InvoiceDate"]) # Type change for date

# %%
data["ToplamHarcama"] = data["Quantity"] * data["UnitPrice"]  # Calculating total payment

# %%
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  ToplamHarcama
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom          15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom          20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom          22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom          20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom          20.34

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 406829 entries, 0 to 541908
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   InvoiceNo      406829 non-null  object
#  1   StockCode      406829 non-null  object
#  2   Description    406829 non-null  object
#  3   Quantity       406829 non-null  int64
#  4   InvoiceDate    406829 non-null  datetime64[ns]
#  5   UnitPrice      406829 non-null  float64
#  6   CustomerID     406829 non-null  float64
#  7   Country        406829 non-null  object
#  8   ToplamHarcama  406829 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(4)
# memory usage: 31.0+ MB

# %%
import datetime as dt

snapshot_date = max(data.InvoiceDate) + dt.timedelta(days=1)

# RFM values calculations
rfm = data.groupby(['CustomerID']).agg({
    'InvoiceDate': lambda x: (snapshot_date - x.max()).days,  
    'InvoiceNo': 'count', 
    'ToplamHarcama': 'sum' 
})

# %%
# Giving new names for R, F and M columns
rfm.rename(columns={'InvoiceDate': 'Recency(Tezelik)',
                    'InvoiceNo': 'Frequency(Sıklık)',
                    'ToplamHarcama': 'MonetaryValue(Parasal)'}, inplace=True)

# %%
rfm
# Out:
#             Recency(Tezelik)  Frequency(Sıklık)  MonetaryValue(Parasal)
# CustomerID
# 12346.0                  326                  2                    0.00
# 12347.0                    2                182                 4310.00
# 12348.0                   75                 31                 1797.24
# 12349.0                   19                 73                 1757.55
# 12350.0                  310                 17                  334.40
# ...                      ...                ...                     ...
# 18280.0                  278                 10                  180.60
# 18281.0                  181                  7                   80.82
# 18282.0                    8                 13                  176.60
# 18283.0                    4                756                 2094.88
# 18287.0                   43                 70                 1837.28
#
# [4372 rows x 3 columns]

# %%
# Giving score to RFM values by splitting 5 parts.

rfm['R_Score'] = pd.qcut(rfm['Recency(Tezelik)'], 5, labels=[5, 4, 3, 2, 1])
rfm['F_Score'] = pd.qcut(rfm['Frequency(Sıklık)'], 5, labels=[1, 2, 3, 4, 5])
rfm['M_Score'] = pd.qcut(rfm['MonetaryValue(Parasal)'], 5, labels=[1, 2, 3, 4, 5])

# %%
rfm
# Out:
#             Recency(Tezelik)  Frequency(Sıklık)  MonetaryValue(Parasal)  \
# CustomerID
# 12346.0                  326                  2                    0.00
# 12347.0                    2                182                 4310.00
# 12348.0                   75                 31                 1797.24
# 12349.0                   19                 73                 1757.55
# 12350.0                  310                 17                  334.40
# ...                      ...                ...                     ...
# 18280.0                  278                 10                  180.60
# 18281.0                  181                  7                   80.82
# 18282.0                    8                 13                  176.60
# 18283.0                    4                756                 2094.88
# 18287.0                   43                 70                 1837.28
#
#            R_Score F_Score M_Score
# CustomerID
# 12346.0          1       1       1
# 12347.0          5       5       5
# 12348.0          2       3       4
# 12349.0          4       4       4
# 12350.0          1       2       2
# ...            ...     ...     ...
# 18280.0          1       1       1
# 18281.0          1       1       1
# 18282.0          5       1       1
# 18283.0          5       5       5
# 18287.0          3       4       4
#
# [4372 rows x 6 columns]

# %%
# Total score for each values and creating segment for them

rfm['RFM_Segment'] = rfm.apply(lambda x: str(x['R_Score']) + str(x['F_Score']) + str(x['M_Score']), axis=1) 
rfm['RFM_Score'] = rfm[['R_Score', 'F_Score', 'M_Score']].sum(axis=1)

# %%
rfm
# Out:
#             Recency(Tezelik)  Frequency(Sıklık)  MonetaryValue(Parasal)  \
# CustomerID
# 12346.0                  326                  2                    0.00
# 12347.0                    2                182                 4310.00
# 12348.0                   75                 31                 1797.24
# 12349.0                   19                 73                 1757.55
# 12350.0                  310                 17                  334.40
# ...                      ...                ...                     ...
# 18280.0                  278                 10                  180.60
# 18281.0                  181                  7                   80.82
# 18282.0                    8                 13                  176.60
# 18283.0                    4                756                 2094.88
# 18287.0                   43                 70                 1837.28
#
#            R_Score F_Score M_Score RFM_Segment  RFM_Score
# CustomerID
# 12346.0          1       1       1   1.01.01.0          3
# 12347.0          5       5       5   5.05.05.0         15
# 12348.0          2       3       4   2.03.04.0          9
# 12349.0          4       4       4   4.04.04.0         12
# 12350.0          1       2       2   1.02.02.0          5
# ...            ...     ...     ...         ...        ...
# 18280.0          1       1       1   1.01.01.0          3
# 18281.0          1       1       1   1.01.01.0          3
# 18282.0          5       1       1   5.01.01.0          7
# 18283.0          5       5       5   5.05.05.0         15
# 18287.0          3       4       4   3.04.04.0         11
#
# [4372 rows x 8 columns]

# %%
# Customer Segment Definition depend on scores
segt_map = {
    r'[1-2][1-2]': 'Uyuyanlar',              # Hibernating
    r'[1-2][3-4]': 'Risk Altında',           # At Risk
    r'[1-2]5': 'Kaybedemeyiz',               # Can’t Lose
    r'3[1-2]': 'Uykuya Dalma Noktasında',    # About To Sleep
    r'33': 'Dikkat Gerektirenler',           # Need Attention
    r'[3-4][4-5]': 'Sadık Müşteriler',       # Loyal Customers
    r'41': 'Umut Verenler',                  # Promising
    r'51': 'Yeni Müşteriler',                # New Customers
    r'[4-5][2-3]': 'Potansiyel Sadıklar',    # Potential Loyalists
    r'5[4-5]': 'Şampiyonlar'                 # Champions
}
rfm['Segment'] = rfm['R_Score'].astype(str) + rfm['F_Score'].astype(str)
rfm['Segment'] = rfm['Segment'].replace(segt_map, regex=True)

# %%
rfm
# Out:
#             Recency(Tezelik)  Frequency(Sıklık)  MonetaryValue(Parasal)  \
# CustomerID
# 12346.0                  326                  2                    0.00
# 12347.0                    2                182                 4310.00
# 12348.0                   75                 31                 1797.24
# 12349.0                   19                 73                 1757.55
# 12350.0                  310                 17                  334.40
# ...                      ...                ...                     ...
# 18280.0                  278                 10                  180.60
# 18281.0                  181                  7                   80.82
# 18282.0                    8                 13                  176.60
# 18283.0                    4                756                 2094.88
# 18287.0                   43                 70                 1837.28
#
#            R_Score F_Score M_Score RFM_Segment  RFM_Score           Segment
# CustomerID
# 12346.0          1       1       1   1.01.01.0          3         Uyuyanlar
# 12347.0          5       5       5   5.05.05.0         15       Şampiyonlar
# 12348.0          2       3       4   2.03.04.0          9      Risk Altında
# 12349.0          4       4       4   4.04.04.0         12  Sadık Müşteriler
# 12350.0          1       2       2   1.02.02.0          5         Uyuyanlar
# ...            ...     ...     ...         ...        ...               ...
# 18280.0          1       1       1   1.01.01.0          3         Uyuyanlar
# 18281.0          1       1       1   1.01.01.0          3         Uyuyanlar
# 18282.0          5       1       1   5.01.01.0          7   Yeni Müşteriler
# 18283.0          5       5       5   5.05.05.0         15       Şampiyonlar
# 18287.0          3       4       4   3.04.04.0         11  Sadık Müşteriler
#
# [4372 rows x 9 columns]

# %%
rfm['Segment'].value_counts() # Segment distrubition
# Out:
# Uyuyanlar                  1070
# Sadık Müşteriler            839
# Şampiyonlar                 604
# Risk Altında                583
# Potansiyel Sadıklar         504
# Uykuya Dalma Noktasında     321
# Dikkat Gerektirenler        202
# Umut Verenler               107
# Kaybedemeyiz                 82
# Yeni Müşteriler              60
# Name: Segment, dtype: int64

# %%
# Segment distubition on graph

sns.countplot(y='Segment', data=rfm, order = rfm['Segment'].value_counts().index)
plt.title('RFM Segment Dağılımı')
plt.xlabel('Sayısı')
plt.ylabel('Segment')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# Scaling data
scaler = StandardScaler()
rfm_numeric = rfm[['Recency(Tezelik)', 'Frequency(Sıklık)', 'MonetaryValue(Parasal)', 'R_Score', 'F_Score', 'M_Score', 'RFM_Score']]

rfm_scaled = scaler.fit_transform(rfm_numeric) # Scale

# %%
rfm_numeric
# Out:
#             Recency(Tezelik)  Frequency(Sıklık)  MonetaryValue(Parasal)  \
# CustomerID
# 12346.0                  326                  2                    0.00
# 12347.0                    2                182                 4310.00
# 12348.0                   75                 31                 1797.24
# 12349.0                   19                 73                 1757.55
# 12350.0                  310                 17                  334.40
# ...                      ...                ...                     ...
# 18280.0                  278                 10                  180.60
# 18281.0                  181                  7                   80.82
# 18282.0                    8                 13                  176.60
# 18283.0                    4                756                 2094.88
# 18287.0                   43                 70                 1837.28
#
#            R_Score F_Score M_Score  RFM_Score
# CustomerID
# 12346.0          1       1       1          3
# 12347.0          5       5       5         15
# 12348.0          2       3       4          9
# 12349.0          4       4       4         12
# 12350.0          1       2       2          5
# ...            ...     ...     ...        ...
# 18280.0          1       1       1          3
# 18281.0          1       1       1          3
# 18282.0          5       1       1          7
# 18283.0          5       5       5         15
# 18287.0          3       4       4         11
#
# [4372 rows x 7 columns]

# %%
rfm_scaled
# Out:
# array([[ 2.32202285e+00, -3.91719701e-01, -2.31000989e-01, ...,
#         -1.39329872e+00, -1.41389020e+00, -1.66688536e+00],
#        [-8.93733232e-01,  3.82656967e-01,  2.93431666e-01, ...,
#          1.41449202e+00,  1.41389020e+00,  1.66942906e+00],
#        [-1.69195597e-01, -2.66959016e-01, -1.23162220e-02, ...,
#          1.05966485e-02,  7.06945101e-01,  1.27184905e-03],
#        ...,
#        [-8.34182193e-01, -3.44396683e-01, -2.09512634e-01, ...,
#         -1.39329872e+00, -1.41389020e+00, -5.54780556e-01],
#        [-8.73882885e-01,  2.85205812e+00,  2.39000508e-02, ...,
#          1.41449202e+00,  1.41389020e+00,  1.66942906e+00],
#        [-4.86801135e-01, -9.91774042e-02, -7.44423043e-03, ...,
#          7.12544334e-01,  7.06945101e-01,  5.57324254e-01]])
